# %%
from pathlib import Path
import csv

path = Path('C:/Users/oscarahe/OneDrive - Intel Corporation/Desktop/GDCWEATHER.csv')
lines = path.read_text(encoding='utf-8').splitlines()

reader = csv.reader(lines)
header_row = next(reader)
print(header_row)
# Out:
# ['\ufeffSTATION', 'NAME', 'DATE', 'TAVG', 'TMAX', 'TMIN']

# %%
for index, column_header in enumerate(header_row):
    print(index, column_header)
# Out:
# 0 ﻿STATION
# 1 NAME
# 2 DATE
# 3 TAVG
# 4 TMAX
# 5 TMIN

# %%
# Extract high temperatures.
highs = []
for row in reader:
      high = int(row[4])
      highs.append(high)

print(highs)
# Out:
# []

# %%
import matplotlib.pyplot as plt
# Plot the high temperatures.
plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots()
ax.plot(highs, color='red')

# Format plot.
ax.set_title("Daily High Temperatures, GDC", fontsize=24)
ax.set_xlabel('', fontsize=16)
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=16)

plt.show()

# %%
from datetime import datetime
first_date = datetime.strptime('2021-07-01', '%Y-%m-%d')
print(first_date)
# Out:
# 2021-07-01 00:00:00

# %%
from datetime import datetime

dates, highs = [], []

current_date = datetime.strptime(row[4],'%Y-%m-%d')
dates.append(current_date)

ax.plot(dates, highs, color='red') 
fig.autofmt_xdate()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[132], line 5
#       1 from datetime import datetime
#       3 dates, highs = [], []
# ----> 5 current_date = datetime.strptime(row[4],'%Y-%m-%d')
#       6 dates.append(current_date)
#       8 ax.plot(dates, highs, color='red')
#
# File c:\users\oscarahe\appdata\local\programs\python\python39\lib\_strptime.py:568, in _strptime_datetime(cls, data_string, format)
#     565 def _strptime_datetime(cls, data_string, format="%a %b %d %H:%M:%S %Y"):
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# ...

# %%
high = int(row[4])
low = int(row[4])

# %%
low
# Out:
# 48

# %%
ValueError: invalid literal for int() with base 10: ''
# Out:
#   Cell In[135], line 1
#     ValueError: invalid literal for int() with base 10: ''
#                         ^
# SyntaxError: invalid syntax

# %%
--snip--
for row in reader:
    current_date = datetime.strptime(row[2], '%Y-%m-%d')
❶     try:
        high = int(row[3])
        low = int(row[4])
    except ValueError:
❷         print(f"Missing data for {current_date}")
❸     else:
        dates.append(current_date)
        highs.append(high)
        lows.append(low)

# Plot the high and low temperatures.
--snip--

# Format plot.
❹ title = "Daily High and Low Temperatures, 2021\nDeath Valley, CA"
ax.set_title(title, fontsize=20)
ax.set_xlabel('', fontsize=16)
--snip--
# Out:
#   File <tokenize>:7
#     except ValueError:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# #### PYTHON CRASH EJEMPLO ####

# %%
path = Path('C:/Users/oscarahe/OneDrive - Intel Corporation/Desktop/weather_data/sitka_weather_07-2021_simple.csv')
lines = path.read_text(encoding='utf-8').splitlines()

# %%
reader = csv.reader(lines)
header_row = next(reader)
print(header_row)
# Out:
# ['STATION', 'NAME', 'DATE', 'TAVG', 'TMAX', 'TMIN']

# %%
for index, column_header in enumerate(header_row):
    print(index, column_header)
# Out:
# 0 STATION
# 1 NAME
# 2 DATE
# 3 TAVG
# 4 TMAX
# 5 TMIN

# %%
# Extract high temperatures.
highs = []
for row in reader:
      high = int(row[4])
      highs.append(high)

print(highs)
# Out:
# [61, 60, 66, 60, 65, 59, 58, 58, 57, 60, 60, 60, 57, 58, 60, 61, 63, 63, 70, 64, 59, 63, 61, 58, 59, 64, 62, 70, 70, 73, 66]

# %%
import matplotlib.pyplot as plt

# Plot the high temperatures.
plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots()
ax.plot(highs, color='red')

# Format plot.
ax.set_title("Daily High Temperatures, July 2021", fontsize=24)
ax.set_xlabel('', fontsize=16)
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=16)

plt.show()

# %%
from datetime import datetime

# %%
ax.set_title("Daily High Temperatures, 2021", fontsize=24)
# Out:
# Text(0.5, 1.0, 'Daily High Temperatures, 2021')

# %%
from pathlib import Path
import csv
from datetime import datetime

import matplotlib.pyplot as plt


path = Path('C:/Users/oscarahe/OneDrive - Intel Corporation/Desktop/weather_data/sitka_weather_07-2021_simple.csv')

lines = path.read_text().splitlines()

reader = csv.reader(lines)
header_row = next(reader)

# Extract dates, and high and low temperatures.
dates, highs, lows = [], [], []
for row in reader:
    current_date = datetime.strptime(row[2], '%Y-%m-%d')
    try:
        high = int(row[3])
        low = int(row[5])
    except ValueError:
        print(f"Missing data for {current_date}")
    else:
        dates.append(current_date)
        highs.append(high)
        lows.append(low)

# Plot the high and low temperatures.
plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots()
ax.plot(dates, highs, color='red', alpha=0.5)
ax.plot(dates, lows, color='blue', alpha=0.5)
ax.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1)

# Format plot.
title = "Daily High and Low Temperatures,GDC 2023-2024"
ax.set_title(title, fontsize=20)
fig.autofmt_xdate()
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=16)

plt.show()
# Out:
# Missing data for 2021-07-01 00:00:00
# Missing data for 2021-07-02 00:00:00
# Missing data for 2021-07-03 00:00:00
# Missing data for 2021-07-04 00:00:00
# Missing data for 2021-07-05 00:00:00
# Missing data for 2021-07-06 00:00:00
# Missing data for 2021-07-07 00:00:00
# Missing data for 2021-07-08 00:00:00
# Missing data for 2021-07-09 00:00:00
# Missing data for 2021-07-10 00:00:00
# Missing data for 2021-07-11 00:00:00
# Missing data for 2021-07-12 00:00:00
# Missing data for 2021-07-13 00:00:00
# Missing data for 2021-07-14 00:00:00
# Missing data for 2021-07-15 00:00:00
# Missing data for 2021-07-16 00:00:00
# Missing data for 2021-07-17 00:00:00
# Missing data for 2021-07-18 00:00:00
# Missing data for 2021-07-19 00:00:00
# Missing data for 2021-07-20 00:00:00
# Missing data for 2021-07-21 00:00:00
# Missing data for 2021-07-22 00:00:00
# Missing data for 2021-07-23 00:00:00
# Missing data for 2021-07-24 00:00:00
# Missing data for 2021-07-25 00:00:00
# ...

# %%
from pathlib import Path
import csv
from datetime import datetime

import matplotlib.pyplot as plt


path = Path('C:/Users/oscarahe/OneDrive - Intel Corporation/Desktop/GDCWEATHER.csv')

lines = path.read_text().splitlines()

reader = csv.reader(lines)
header_row = next(reader)

# Extract dates, and high and low temperatures.
dates, highs, lows = [], [], []
for row in reader:
    current_date = datetime.strptime(row[2], '%m/%d/%Y')
    try:
        high = int(row[3])
        low = int(row[5])
    except ValueError:
        print(f"Missing data for {current_date}")
    else:
        dates.append(current_date)
        highs.append(high)
        lows.append(low)

# Plot the high and low temperatures.
plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots()
ax.plot(dates, highs, color='red', alpha=0.5)
ax.plot(dates, lows, color='blue', alpha=0.5)
ax.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1)

# Format plot.
title = "Daily High and Low Temperatures,GDC 2023-2024"
ax.set_title(title, fontsize=20)
fig.autofmt_xdate()
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=16)

plt.show()
# Out:
# Missing data for 2023-01-01 00:00:00
# Missing data for 2023-01-03 00:00:00
# Missing data for 2023-01-05 00:00:00
# Missing data for 2023-01-17 00:00:00
# Missing data for 2023-01-29 00:00:00
# Missing data for 2023-02-05 00:00:00
# Missing data for 2023-02-24 00:00:00
# Missing data for 2023-02-27 00:00:00
# Missing data for 2023-03-03 00:00:00
# Missing data for 2023-03-05 00:00:00
# Missing data for 2023-03-22 00:00:00
# Missing data for 2023-04-01 00:00:00
# Missing data for 2023-04-05 00:00:00
# Missing data for 2023-04-08 00:00:00
# Missing data for 2023-05-31 00:00:00
# Missing data for 2023-06-01 00:00:00
# Missing data for 2023-06-04 00:00:00
# Missing data for 2023-06-09 00:00:00
# Missing data for 2023-06-11 00:00:00
# Missing data for 2023-06-13 00:00:00
# Missing data for 2023-06-17 00:00:00
# Missing data for 2023-06-19 00:00:00
# ...

# %%
print(max(lows))
# Out:
# 67

# %%
clima=pd.read_csv('C:/Users/oscarahe/OneDrive - Intel Corporation/Desktop/GDCWEATHER.csv')
clima
# Out:
#          STATION             NAME       DATE  TAVG  TMAX  TMIN
# 0    MXM00076612  GUADALAJARA, MX   1/1/2023    62   NaN   NaN
# 1    MXM00076612  GUADALAJARA, MX   1/2/2023    60  76.0  46.0
# 2    MXM00076612  GUADALAJARA, MX   1/3/2023    60   NaN   NaN
# 3    MXM00076612  GUADALAJARA, MX   1/4/2023    62  78.0  45.0
# 4    MXM00076612  GUADALAJARA, MX   1/5/2023    59   NaN   NaN
# ..           ...              ...        ...   ...   ...   ...
# 380  MXM00076612  GUADALAJARA, MX  3/15/2024    69  91.0  50.0
# 381  MXM00076612  GUADALAJARA, MX  3/16/2024    69  90.0  50.0
# 382  MXM00076612  GUADALAJARA, MX  3/17/2024    78  92.0  52.0
# 383  MXM00076612  GUADALAJARA, MX  3/18/2024    71  92.0  48.0
# 384  MXM00076612  GUADALAJARA, MX  3/19/2024    73  92.0  48.0
#
# [385 rows x 6 columns]

# %%
clima.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 385 entries, 0 to 384
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   STATION  385 non-null    object
#  1   NAME     385 non-null    object
#  2   DATE     385 non-null    object
#  3   TAVG     385 non-null    int64
#  4   TMAX     294 non-null    float64
#  5   TMIN     294 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 18.2+ KB

# %%
clima.query('TMAX==105')
# Out:
#          STATION             NAME       DATE  TAVG   TMAX  TMIN
# 113  MXM00076612  GUADALAJARA, MX  6/14/2023    87  105.0  64.0

# %%
clima.query('TMAX==72')
# Out:
#          STATION             NAME        DATE  TAVG  TMAX  TMIN
# 302  MXM00076612  GUADALAJARA, MX  12/26/2023    58  72.0  48.0

# %%
clima.query('TAVG==87')
# Out:
#          STATION             NAME       DATE  TAVG   TMAX  TMIN
# 100  MXM00076612  GUADALAJARA, MX   6/1/2023    87    NaN   NaN
# 112  MXM00076612  GUADALAJARA, MX  6/13/2023    87    NaN   NaN
# 113  MXM00076612  GUADALAJARA, MX  6/14/2023    87  105.0  64.0
# 120  MXM00076612  GUADALAJARA, MX  6/21/2023    87  101.0  65.0
# 122  MXM00076612  GUADALAJARA, MX  6/23/2023    87  103.0  67.0

# %%
clima.query('TAVG==53')
# Out:
#          STATION             NAME        DATE  TAVG  TMAX  TMIN
# 304  MXM00076612  GUADALAJARA, MX  12/28/2023    53  73.0  40.0

# %%
clima.query('TMIN==37')
# Out:
#         STATION             NAME       DATE  TAVG  TMAX  TMIN
# 17  MXM00076612  GUADALAJARA, MX  1/18/2023    58  82.0  37.0

# %%
clima.query('TMIN==67')
# Out:
#          STATION             NAME       DATE  TAVG   TMAX  TMIN
# 122  MXM00076612  GUADALAJARA, MX  6/23/2023    87  103.0  67.0
# 123  MXM00076612  GUADALAJARA, MX  6/24/2023    83  100.0  67.0
