# %%
import pandas as pd
import numpy as np

# %%
games=pd.read_csv("games.csv")
games
# Out:
#         GAME_DATE   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0      12/19/2020  12000047            Final    1610612753       1610612766
# 1      12/19/2020  12000048            Final    1610612764       1610612765
# 2      12/19/2020  12000049            Final    1610612763       1610612737
# 3      12/18/2020  12000039            Final    1610612754       1610612755
# 4      12/18/2020  12000040            Final    1610612761       1610612748
# ...           ...       ...              ...           ...              ...
# 23416   10/6/2014  11400007            Final    1610612737       1610612740
# 23417   10/6/2014  11400004            Final    1610612741       1610612764
# 23418   10/6/2014  11400005            Final    1610612747       1610612743
# 23419   10/5/2014  11400002            Final    1610612761       1610612758
# 23420   10/4/2014  11400001            Final    1610612748       1610612740
#
#        SEASON  TEAM_ID_home  POINTS_home  FG_PCT_home  FT_PCT_home  ...  \
# 0        2020    1610612753          120        0.433        0.792  ...
# 1        2020    1610612764           99        0.427        0.625  ...
# 2        2020    1610612763          116        0.400        0.744  ...
# 3        2020    1610612754          107        0.371        0.692  ...
# 4        2020    1610612761          105        0.380        0.737  ...
# ...       ...           ...          ...          ...          ...  ...
# 23416    2014    1610612737           93        0.419        0.821  ...
# 23417    2014    1610612741           81        0.338        0.719  ...
# 23418    2014    1610612747           98        0.448        0.682  ...
# 23419    2014    1610612761           99        0.440        0.771  ...
# 23420    2014    1610612748           86        0.431        0.679  ...
#
#        AST_home  REB_home  TEAM_ID_away  POINTS_away  FG_PCT_away  \
# 0            23        50    1610612766          117        0.444
# 1            24        45    1610612765           96        0.402
# 2            21        43    1610612737          117        0.422
# 3            19        45    1610612755          113        0.533
# 4            27        37    1610612748          117        0.534
# ...         ...       ...           ...          ...          ...
# 23416        24        50    1610612740           87        0.366
# 23417        18        40    1610612764           85        0.411
# 23418        29        45    1610612743           95        0.387
# 23419        21        30    1610612758           94        0.469
# 23420        18        42    1610612740           98        0.462
#
#        FT_PCT_away  FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS
# 0            0.864         0.439        21        52               1
# 1            0.647         0.326        18        51               1
# 2            0.837         0.297        24        47               0
# 3            0.629         0.355        23        48               0
# 4            0.741         0.514        30        51               0
# ...            ...           ...       ...       ...             ...
# 23416        0.643         0.375        17        43               1
# 23417        0.636         0.267        17        47               0
# 23418        0.659         0.500        19        43               1
# 23419        0.725         0.385        18        45               1
# 23420        0.706         0.438        19        42               0
#
# [23421 rows x 21 columns]

# %%
games.head(5)
# Out:
#     GAME_DATE   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0  12/19/2020  12000047            Final    1610612753       1610612766
# 1  12/19/2020  12000048            Final    1610612764       1610612765
# 2  12/19/2020  12000049            Final    1610612763       1610612737
# 3  12/18/2020  12000039            Final    1610612754       1610612755
# 4  12/18/2020  12000040            Final    1610612761       1610612748
#
#    SEASON  TEAM_ID_home  POINTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2020    1610612753          120        0.433        0.792  ...        23
# 1    2020    1610612764           99        0.427        0.625  ...        24
# 2    2020    1610612763          116        0.400        0.744  ...        21
# 3    2020    1610612754          107        0.371        0.692  ...        19
# 4    2020    1610612761          105        0.380        0.737  ...        27
#
#    REB_home  TEAM_ID_away  POINTS_away  FG_PCT_away  FT_PCT_away  \
# 0        50    1610612766          117        0.444        0.864
# 1        45    1610612765           96        0.402        0.647
# 2        43    1610612737          117        0.422        0.837
# 3        45    1610612755          113        0.533        0.629
# 4        37    1610612748          117        0.534        0.741
#
#    FG3_PCT_away  AST_away  REB_away  HOME_TEAM_WINS
# 0         0.439        21        52               1
# 1         0.326        18        51               1
# 2         0.297        24        47               0
# 3         0.355        23        48               0
# 4         0.514        30        51               0
#
# [5 rows x 21 columns]

# %%
games.columns
# Out:
# Index(['GAME_DATE', 'GAME_ID', 'GAME_STATUS_TEXT', 'HOME_TEAM_ID',
#        'VISITOR_TEAM_ID', 'SEASON', 'TEAM_ID_home', 'POINTS_home',
#        'FG_PCT_home', 'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home',
#        'TEAM_ID_away', 'POINTS_away', 'FG_PCT_away', 'FT_PCT_away',
#        'FG3_PCT_away', 'AST_away', 'REB_away', 'HOME_TEAM_WINS'],
#       dtype='object')

# %%
####SUBSET DE COLUMNAS
games=games[['GAME_DATE', 'GAME_STATUS_TEXT', 'TEAM_ID_home', 'TEAM_ID_away', 'POINTS_home', 'POINTS_away', 'HOME_TEAM_WINS']]
games
# Out:
#         GAME_DATE GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  POINTS_home  \
# 0      12/19/2020            Final    1610612753    1610612766          120
# 1      12/19/2020            Final    1610612764    1610612765           99
# 2      12/19/2020            Final    1610612763    1610612737          116
# 3      12/18/2020            Final    1610612754    1610612755          107
# 4      12/18/2020            Final    1610612761    1610612748          105
# ...           ...              ...           ...           ...          ...
# 23416   10/6/2014            Final    1610612737    1610612740           93
# 23417   10/6/2014            Final    1610612741    1610612764           81
# 23418   10/6/2014            Final    1610612747    1610612743           98
# 23419   10/5/2014            Final    1610612761    1610612758           99
# 23420   10/4/2014            Final    1610612748    1610612740           86
#
#        POINTS_away  HOME_TEAM_WINS
# 0              117               1
# 1               96               1
# 2              117               0
# 3              113               0
# 4              117               0
# ...            ...             ...
# 23416           87               1
# 23417           85               0
# 23418           95               1
# 23419           94               1
# 23420           98               0
#
# [23421 rows x 7 columns]

# %%
games.head(5)
# Out:
# 0   2020-12-19
# 1   2020-12-19
# 2   2020-12-19
# 3   2020-12-18
# 4   2020-12-18
# Name: GAME_DATE, dtype: datetime64[ns]

# %%
games= pd.to_datetime(games['GAME_DATE'])
games
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 games= pd.to_datetime(games['GAME_DATE'])
#       2 games
#
# File c:\users\oscarahe\appdata\local\programs\python\python39\lib\site-packages\pandas\core\series.py:1111, in Series.__getitem__(self, key)
#    1108     return self._values[key]
#    1110 elif key_is_scalar:
# -> 1111     return self._get_value(key)
#    1113 # Convert generator to list before going through hashable part
#    1114 # (We will iterate through the generator there to check for slices)
#    1115 if is_iterator(key):
#
# File c:\users\oscarahe\appdata\local\programs\python\python39\lib\site-packages\pandas\core\series.py:1227, in Series._get_value(self, label, takeable)
#    1224     return self._values[label]
#    1226 # Similar to Index.get_value, but we do not fall back to positional
# -> 1227 loc = self.index.get_loc(label)
#    1229 if is_integer(loc):
#    1230     return self._values[loc]
#
# File c:\users\oscarahe\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'GAME_DATE'

# %%
games = games.astype({'GAMES_STATUS_TEXT': 'string'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12316\2265565704.py in ?()
# ----> 1 games = games.astype({'GAMES_STATUS_TEXT': 'string'})
#
# c:\users\oscarahe\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy, errors)
#    6580
#    6581         if is_dict_like(dtype):
#    6582             if self.ndim == 1:  # i.e. Series
#    6583                 if len(dtype) > 1 or self.name not in dtype:
# -> 6584                     raise KeyError(
#    6585                         "Only the Series name can be used for "
#    6586                         "the key in Series dtype mappings."
#    6587                     )
#
# KeyError: 'Only the Series name can be used for the key in Series dtype mappings.'

# %%
games.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 23421 entries, 0 to 23420
# Series name: GAME_DATE
# Non-Null Count  Dtype
# --------------  -----
# 23421 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 183.1 KB

# %%
teams=pd.read_csv('teams.csv')
teams.head(5)
# Out:
#    LEAGUE_ID     TEAM_ID  MIN_YEAR  MAX_YEAR ABBREVIATION   NICKNAME  \
# 0          0  1610612737      1949      2019          ATL      Hawks
# 1          0  1610612738      1946      2019          BOS    Celtics
# 2          0  1610612740      2002      2019          NOP   Pelicans
# 3          0  1610612741      1966      2019          CHI      Bulls
# 4          0  1610612742      1980      2019          DAL  Mavericks
#
#    YEARFOUNDED         CITY                     ARENA  ARENACAPACITY  \
# 0         1949      Atlanta          State Farm Arena        18729.0
# 1         1946       Boston                 TD Garden        18624.0
# 2         2002  New Orleans      Smoothie King Center            NaN
# 3         1966      Chicago             United Center        21711.0
# 4         1980       Dallas  American Airlines Center        19200.0
#
#              OWNER  GENERALMANAGER      HEADCOACH DLEAGUEAFFILIATION
# 0     Tony Ressler  Travis Schlenk   Lloyd Pierce      Erie Bayhawks
# 1    Wyc Grousbeck     Danny Ainge   Brad Stevens    Maine Red Claws
# 2       Tom Benson  Trajan Langdon   Alvin Gentry       No Affiliate
# 3  Jerry Reinsdorf      Gar Forman     Jim Boylen   Windy City Bulls
# 4       Mark Cuban   Donnie Nelson  Rick Carlisle      Texas Legends

# %%
teams=teams[['TEAM_ID', 'CITY', 'NICKNAME']]
teams.head(5).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   TEAM_ID   5 non-null      int64
#  1   CITY      5 non-null      object
#  2   NICKNAME  5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 248.0+ bytes

# %%
teams = teams.astype({'CITY': 'string', 'NICKNAME': 'string'})

# %%
teams.dtypes
# Out:
# TEAM_ID              int64
# CITY        string[python]
# NICKNAME    string[python]
# dtype: object

# %%
teams.head(2)
# Out:
#       TEAM_ID     CITY NICKNAME
# 0  1610612737  Atlanta    Hawks
# 1  1610612738   Boston  Celtics

# %%
games.head(2)
# Out:
#     GAME_DATE GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  POINTS_home  \
# 0  12/19/2020            Final    1610612753    1610612766          120
# 1  12/19/2020            Final    1610612764    1610612765           99
#
#    POINTS_away  HOME_TEAM_WINS
# 0          117               1
# 1           96               1

# %% [markdown]
# * Within the games DataFrame, there are two columns TEAM_ID_home and TEAM_ID_away. This is because each game involves two teams playing against each other. The team that played in its own location, is called the home team, the team that played outside its location, is called the away team. Each game has one home team and one away team.
# *
# While the teams DataFrame stores the information about each team, the identifier for each team is the column TEAM_ID.*
#
# We can merge the two DataFrames base o* n:
#
# TEAM_ID_home in games and TEAM_ID in teams: to get the team information fo the'home'*  team
# TEAM_ID_away in games and TEAM_ID in teams: to get the team information fr th 'away' team

# %%
games_with_home_team = pd.merge(games, teams, left_on='TEAM_ID_home', right_on='TEAM_ID', how='inner')
games_with_home_team
# Out:
#         GAME_DATE GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  POINTS_home  \
# 0      12/19/2020            Final    1610612753    1610612766          120
# 1      12/19/2020            Final    1610612764    1610612765           99
# 2      12/19/2020            Final    1610612763    1610612737          116
# 3      12/18/2020            Final    1610612754    1610612755          107
# 4      12/18/2020            Final    1610612761    1610612748          105
# ...           ...              ...           ...           ...          ...
# 23416   10/6/2014            Final    1610612737    1610612740           93
# 23417   10/6/2014            Final    1610612741    1610612764           81
# 23418   10/6/2014            Final    1610612747    1610612743           98
# 23419   10/5/2014            Final    1610612761    1610612758           99
# 23420   10/4/2014            Final    1610612748    1610612740           86
#
#        POINTS_away  HOME_TEAM_WINS     TEAM_ID         CITY   NICKNAME
# 0              117               1  1610612753      Orlando      Magic
# 1               96               1  1610612764   Washington    Wizards
# 2              117               0  1610612763      Memphis  Grizzlies
# 3              113               0  1610612754      Indiana     Pacers
# 4              117               0  1610612761      Toronto    Raptors
# ...            ...             ...         ...          ...        ...
# 23416           87               1  1610612737      Atlanta      Hawks
# 23417           85               0  1610612741      Chicago      Bulls
# 23418           95               1  1610612747  Los Angeles     Lakers
# 23419           94               1  1610612761      Toronto    Raptors
# 23420           98               0  1610612748        Miami       Heat
#
# [23421 rows x 10 columns]

# %%
games_with_home_team.head()
# Out:
#     GAME_DATE GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  POINTS_home  \
# 0  12/19/2020            Final    1610612753    1610612766          120
# 1  12/19/2020            Final    1610612764    1610612765           99
# 2  12/19/2020            Final    1610612763    1610612737          116
# 3  12/18/2020            Final    1610612754    1610612755          107
# 4  12/18/2020            Final    1610612761    1610612748          105
#
#    POINTS_away  HOME_TEAM_WINS     TEAM_ID        CITY   NICKNAME
# 0          117               1  1610612753     Orlando      Magic
# 1           96               1  1610612764  Washington    Wizards
# 2          117               0  1610612763     Memphis  Grizzlies
# 3          113               0  1610612754     Indiana     Pacers
# 4          117               0  1610612761     Toronto    Raptors

# %% [markdown]
# #### Rename the column CITY as 'city_home', NICKNAME as 'nickname_home'

# %%
games_with_home_team = games_with_home_team.rename(columns={'CITY': 'city_home', 
                                                            'NICKNAME': 'nickname_home'})

games_with_home_team
# Out:
#         GAME_DATE GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  POINTS_home  \
# 0      12/19/2020            Final    1610612753    1610612766          120
# 1      12/19/2020            Final    1610612764    1610612765           99
# 2      12/19/2020            Final    1610612763    1610612737          116
# 3      12/18/2020            Final    1610612754    1610612755          107
# 4      12/18/2020            Final    1610612761    1610612748          105
# ...           ...              ...           ...           ...          ...
# 23416   10/6/2014            Final    1610612737    1610612740           93
# 23417   10/6/2014            Final    1610612741    1610612764           81
# 23418   10/6/2014            Final    1610612747    1610612743           98
# 23419   10/5/2014            Final    1610612761    1610612758           99
# 23420   10/4/2014            Final    1610612748    1610612740           86
#
#        POINTS_away  HOME_TEAM_WINS     TEAM_ID    city_home nickname_home
# 0              117               1  1610612753      Orlando         Magic
# 1               96               1  1610612764   Washington       Wizards
# 2              117               0  1610612763      Memphis     Grizzlies
# 3              113               0  1610612754      Indiana        Pacers
# 4              117               0  1610612761      Toronto       Raptors
# ...            ...             ...         ...          ...           ...
# 23416           87               1  1610612737      Atlanta         Hawks
# 23417           85               0  1610612741      Chicago         Bulls
# 23418           95               1  1610612747  Los Angeles        Lakers
# 23419           94               1  1610612761      Toronto       Raptors
# 23420           98               0  1610612748        Miami          Heat
#
# [23421 rows x 10 columns]

# %%
games_with_home_team.head(2)
# Out:
#     GAME_DATE GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  POINTS_home  \
# 0  12/19/2020            Final    1610612753    1610612766          120
# 1  12/19/2020            Final    1610612764    1610612765           99
#
#    POINTS_away  HOME_TEAM_WINS     TEAM_ID   city_home nickname_home
# 0          117               1  1610612753     Orlando         Magic
# 1           96               1  1610612764  Washington       Wizards

# %% [markdown]
# * **Merge (inner) games_with_home_team and teams based on 'TEAM_ID_away' and 'TEAM_ID', call the merged DataFrame games_with_both_teams**

# %%
games_with_both_teams = pd.merge(games_with_home_team, teams, left_on='TEAM_ID_away', right_on='TEAM_ID')
# Out:
#         GAME_DATE GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  POINTS_home  \
# 0      12/19/2020            Final    1610612753    1610612766          120
# 1      12/19/2020            Final    1610612764    1610612765           99
# 2      12/19/2020            Final    1610612763    1610612737          116
# 3      12/18/2020            Final    1610612754    1610612755          107
# 4      12/18/2020            Final    1610612761    1610612748          105
# ...           ...              ...           ...           ...          ...
# 23416   10/6/2014            Final    1610612737    1610612740           93
# 23417   10/6/2014            Final    1610612741    1610612764           81
# 23418   10/6/2014            Final    1610612747    1610612743           98
# 23419   10/5/2014            Final    1610612761    1610612758           99
# 23420   10/4/2014            Final    1610612748    1610612740           86
#
#        POINTS_away  HOME_TEAM_WINS   TEAM_ID_x    city_home nickname_home  \
# 0              117               1  1610612753      Orlando         Magic
# 1               96               1  1610612764   Washington       Wizards
# 2              117               0  1610612763      Memphis     Grizzlies
# 3              113               0  1610612754      Indiana        Pacers
# 4              117               0  1610612761      Toronto       Raptors
# ...            ...             ...         ...          ...           ...
# 23416           87               1  1610612737      Atlanta         Hawks
# 23417           85               0  1610612741      Chicago         Bulls
# 23418           95               1  1610612747  Los Angeles        Lakers
# 23419           94               1  1610612761      Toronto       Raptors
# 23420           98               0  1610612748        Miami          Heat
#
#         TEAM_ID_y          CITY  NICKNAME
# 0      1610612766     Charlotte   Hornets
# 1      1610612765       Detroit   Pistons
# 2      1610612737       Atlanta     Hawks
# 3      1610612755  Philadelphia     76ers
# 4      1610612748         Miami      Heat
# ...           ...           ...       ...
# 23416  1610612740   New Orleans  Pelicans
# 23417  1610612764    Washington   Wizards
# 23418  1610612743        Denver   Nuggets
# 23419  1610612758    Sacramento     Kings
# 23420  1610612740   New Orleans  Pelicans
#
# [23421 rows x 13 columns]

# %%
games_with_both_teams.head()
# Out:
#     GAME_DATE GAME_STATUS_TEXT  TEAM_ID_home  TEAM_ID_away  POINTS_home  \
# 0  12/19/2020            Final    1610612753    1610612766          120
# 1  12/19/2020            Final    1610612764    1610612765           99
# 2  12/19/2020            Final    1610612763    1610612737          116
# 3  12/18/2020            Final    1610612754    1610612755          107
# 4  12/18/2020            Final    1610612761    1610612748          105
#
#    POINTS_away  HOME_TEAM_WINS   TEAM_ID_x   city_home nickname_home  \
# 0          117               1  1610612753     Orlando         Magic
# 1           96               1  1610612764  Washington       Wizards
# 2          117               0  1610612763     Memphis     Grizzlies
# 3          113               0  1610612754     Indiana        Pacers
# 4          117               0  1610612761     Toronto       Raptors
#
#     TEAM_ID_y          CITY NICKNAME
# 0  1610612766     Charlotte  Hornets
# 1  1610612765       Detroit  Pistons
# 2  1610612737       Atlanta    Hawks
# 3  1610612755  Philadelphia    76ers
# 4  1610612748         Miami     Heat

# %%
games_with_both_teams = games_with_both_teams.drop(columns=['TEAM_ID_home', 'TEAM_ID_away', 'TEAM_ID_x', 'TEAM_ID_y'])
games_with_both_teams.head()
# Out:
#     GAME_DATE GAME_STATUS_TEXT  POINTS_home  POINTS_away  HOME_TEAM_WINS  \
# 0  12/19/2020            Final          120          117               1
# 1  12/19/2020            Final           99           96               1
# 2  12/19/2020            Final          116          117               0
# 3  12/18/2020            Final          107          113               0
# 4  12/18/2020            Final          105          117               0
#
#     city_home nickname_home          CITY NICKNAME
# 0     Orlando         Magic     Charlotte  Hornets
# 1  Washington       Wizards       Detroit  Pistons
# 2     Memphis     Grizzlies       Atlanta    Hawks
# 3     Indiana        Pacers  Philadelphia    76ers
# 4     Toronto       Raptors         Miami     Heat

# %%
games=games_with_both_teams.copy()

# %%
games.columns = games.columns.str.lower()
games
# Out:
#         game_date game_status_text  points_home  points_away  home_team_wins  \
# 0      12/19/2020            Final          120          117               1
# 1      12/19/2020            Final           99           96               1
# 2      12/19/2020            Final          116          117               0
# 3      12/18/2020            Final          107          113               0
# 4      12/18/2020            Final          105          117               0
# ...           ...              ...          ...          ...             ...
# 23416   10/6/2014            Final           93           87               1
# 23417   10/6/2014            Final           81           85               0
# 23418   10/6/2014            Final           98           95               1
# 23419   10/5/2014            Final           99           94               1
# 23420   10/4/2014            Final           86           98               0
#
#          city_home nickname_home          city  nickname
# 0          Orlando         Magic     Charlotte   Hornets
# 1       Washington       Wizards       Detroit   Pistons
# 2          Memphis     Grizzlies       Atlanta     Hawks
# 3          Indiana        Pacers  Philadelphia     76ers
# 4          Toronto       Raptors         Miami      Heat
# ...            ...           ...           ...       ...
# 23416      Atlanta         Hawks   New Orleans  Pelicans
# 23417      Chicago         Bulls    Washington   Wizards
# 23418  Los Angeles        Lakers        Denver   Nuggets
# 23419      Toronto       Raptors    Sacramento     Kings
# 23420        Miami          Heat   New Orleans  Pelicans
#
# [23421 rows x 9 columns]

# %%
games.columns
# Out:
# Index(['game_date', 'game_status_text', 'points_home', 'points_away',
#        'home_team_wins', 'city_home', 'nickname_home', 'city', 'nickname'],
#       dtype='object')

# %%
games.shape
# Out:
# (23421, 9)

# %%
games.to_csv('games_transformed.csv',index=False)

# %% [markdown]
# * SELECT ALL THE COLLUMNS OF NUMBER DTYPES FROM GAMES

# %%
games.select_dtypes(include='number')
# Out:
#        points_home  points_away  home_team_wins
# 0              120          117               1
# 1               99           96               1
# 2              116          117               0
# 3              107          113               0
# 4              105          117               0
# ...            ...          ...             ...
# 23416           93           87               1
# 23417           81           85               0
# 23418           98           95               1
# 23419           99           94               1
# 23420           86           98               0
#
# [23421 rows x 3 columns]

# %%
games.select_dtypes(exclude='number')
# Out:
#         game_date game_status_text    city_home nickname_home          city  \
# 0      12/19/2020            Final      Orlando         Magic     Charlotte
# 1      12/19/2020            Final   Washington       Wizards       Detroit
# 2      12/19/2020            Final      Memphis     Grizzlies       Atlanta
# 3      12/18/2020            Final      Indiana        Pacers  Philadelphia
# 4      12/18/2020            Final      Toronto       Raptors         Miami
# ...           ...              ...          ...           ...           ...
# 23416   10/6/2014            Final      Atlanta         Hawks   New Orleans
# 23417   10/6/2014            Final      Chicago         Bulls    Washington
# 23418   10/6/2014            Final  Los Angeles        Lakers        Denver
# 23419   10/5/2014            Final      Toronto       Raptors    Sacramento
# 23420   10/4/2014            Final        Miami          Heat   New Orleans
#
#        nickname
# 0       Hornets
# 1       Pistons
# 2         Hawks
# 3         76ers
# 4          Heat
# ...         ...
# 23416  Pelicans
# 23417   Wizards
# 23418   Nuggets
# 23419     Kings
# 23420  Pelicans
#
# [23421 rows x 6 columns]

# %%
#SELECT ROW WITH LEBEL 0
games.loc[0]
# Out:
# game_date           12/19/2020
# game_status_text         Final
# points_home                120
# points_away                117
# home_team_wins               1
# city_home              Orlando
# nickname_home            Magic
# city                 Charlotte
# nickname               Hornets
# Name: 0, dtype: object

# %%
games.iloc[0]
# Out:
# game_date           12/19/2020
# game_status_text         Final
# points_home                120
# points_away                117
# home_team_wins               1
# city_home              Orlando
# nickname_home            Magic
# city                 Charlotte
# nickname               Hornets
# Name: 0, dtype: object

# %%
games=games.set_index('game_date')

# %%
games.index
# Out:
# Index(['10/19/2007', '10/8/2003', '11/9/2004', '3/13/2005', '11/1/2003',
#        '11/4/2003', '10/22/2004', '10/24/2005', '11/16/2014', '5/3/2004',
#        ...
#        '2/22/2019', '12/22/2018', '12/27/2006', '4/6/2008', '1/10/2019',
#        '1/22/2006', '7/31/2020', '10/30/2019', '12/7/2006', '3/1/2019'],
#       dtype='object', name='game_date', length=23421)

# %%
games.loc['12/18/2020']
# Out:
#            game_status_text  points_home  points_away  home_team_wins  \
# game_date
# 12/18/2020            Final          119           83               1
# 12/18/2020            Final           89          113               0
# 12/18/2020            Final          103          105               0
# 12/18/2020            Final          107          113               0
# 12/18/2020            Final          105          117               0
# 12/18/2020            Final          129           96               1
# 12/18/2020            Final          113          114               0
# 12/18/2020            Final          127          113               1
#
#                 city_home nickname_home          city       nickname  \
# game_date
# 12/18/2020       New York        Knicks     Cleveland      Cavaliers
# 12/18/2020         Boston       Celtics      Brooklyn           Nets
# 12/18/2020  Oklahoma City       Thunder       Chicago          Bulls
# 12/18/2020        Indiana        Pacers  Philadelphia          76ers
# 12/18/2020        Toronto       Raptors         Miami           Heat
# 12/18/2020         Denver       Nuggets      Portland  Trail Blazers
# 12/18/2020        Phoenix          Suns   Los Angeles         Lakers
# 12/18/2020    New Orleans      Pelicans     Milwaukee          Bucks
#
#             points_total
# game_date
# 12/18/2020           202
# 12/18/2020           202
# 12/18/2020           208
# 12/18/2020           220
# 12/18/2020           222
# 12/18/2020           225
# 12/18/2020           227
# 12/18/2020           240

# %%
games.loc[['12/18/2020','12/18/2019']]
# Out:
#            game_status_text  points_home  points_away  home_team_wins  \
# game_date
# 12/18/2020            Final          119           83               1
# 12/18/2020            Final           89          113               0
# 12/18/2020            Final          103          105               0
# 12/18/2020            Final          107          113               0
# 12/18/2020            Final          105          117               0
# 12/18/2020            Final          129           96               1
# 12/18/2020            Final          113          114               0
# 12/18/2020            Final          127          113               1
# 12/18/2019            Final          100           98               1
# 12/18/2019            Final           99          107               0
# 12/18/2019            Final           99          112               0
# 12/18/2019            Final          103          109               0
# 12/18/2019            Final          104          108               0
# 12/18/2019            Final          113          104               1
# 12/18/2019            Final          109          110               0
# 12/18/2019            Final          122          112               1
# 12/18/2019            Final          126          122               1
#
#                 city_home  nickname_home          city       nickname  \
# game_date
# 12/18/2020       New York         Knicks     Cleveland      Cavaliers
# 12/18/2020         Boston        Celtics      Brooklyn           Nets
# 12/18/2020  Oklahoma City        Thunder       Chicago          Bulls
# 12/18/2020        Indiana         Pacers  Philadelphia          76ers
# 12/18/2020        Toronto        Raptors         Miami           Heat
# 12/18/2020         Denver        Nuggets      Portland  Trail Blazers
# 12/18/2020        Phoenix           Suns   Los Angeles         Lakers
# 12/18/2020    New Orleans       Pelicans     Milwaukee          Bucks
# 12/18/2019      Cleveland      Cavaliers     Charlotte        Hornets
# 12/18/2019      Minnesota   Timberwolves   New Orleans       Pelicans
# 12/18/2019        Detroit        Pistons       Toronto        Raptors
# 12/18/2019         Dallas      Mavericks        Boston        Celtics
# 12/18/2019   Philadelphia          76ers         Miami           Heat
# 12/18/2019         Denver        Nuggets       Orlando          Magic
# 12/18/2019     Washington        Wizards       Chicago          Bulls
# 12/18/2019       Portland  Trail Blazers  Golden State       Warriors
# 12/18/2019  Oklahoma City        Thunder       Memphis      Grizzlies
#
#             points_total
# game_date
# 12/18/2020           202
# 12/18/2020           202
# 12/18/2020           208
# 12/18/2020           220
# 12/18/2020           222
# 12/18/2020           225
# 12/18/2020           227
# 12/18/2020           240
# 12/18/2019           198
# 12/18/2019           206
# 12/18/2019           211
# 12/18/2019           212
# 12/18/2019           212
# 12/18/2019           217
# 12/18/2019           219
# 12/18/2019           234
# 12/18/2019           248

# %%
games[games['points_home']>150]
# Out:
#            game_status_text  points_home  points_away  home_team_wins  \
# game_date
# 8/25/2020             Final          154          111               1
# 1/28/2020             Final          151          131               1
# 1/26/2020             Final          152          133               1
# 3/16/2010             Final          152          114               1
# 4/6/2008              Final          151          147               1
# 3/16/2008             Final          168          116               1
# 12/27/2006            Final          151          145               1
# 12/7/2006             Final          157          161               0
# 11/30/2019            Final          158          111               1
# 10/30/2019            Final          158          159               0
# 3/1/2019              Final          161          168               0
# 1/10/2019             Final          154          147               1
#
#                 city_home nickname_home           city      nickname
# game_date
# 8/25/2020     Los Angeles      Clippers         Dallas     Mavericks
# 1/28/2020       Milwaukee         Bucks     Washington       Wizards
# 1/26/2020         Atlanta         Hawks     Washington       Wizards
# 3/16/2010         Phoenix          Suns      Minnesota  Timberwolves
# 4/6/2008    Oklahoma City       Thunder         Denver       Nuggets
# 3/16/2008          Denver       Nuggets  Oklahoma City       Thunder
# 12/27/2006       New York        Knicks        Detroit       Pistons
# 12/7/2006        Brooklyn          Nets        Phoenix          Suns
# 11/30/2019        Houston       Rockets        Atlanta         Hawks
# 10/30/2019     Washington       Wizards        Houston       Rockets
# 3/1/2019          Atlanta         Hawks        Chicago         Bulls
# 1/10/2019     San Antonio         Spurs  Oklahoma City       Thunder

# %% [markdown]
# * Select the rows with points_home greater than 150, and home_team_wins not being 1

# %%
games[(games['points_home']>150)&(games['home_team_wins']!=1)]
# Out:
#            game_status_text  points_home  points_away  home_team_wins  \
# game_date
# 12/7/2006             Final          157          161               0
# 10/30/2019            Final          158          159               0
# 3/1/2019              Final          161          168               0
#
#              city_home nickname_home     city nickname
# game_date
# 12/7/2006     Brooklyn          Nets  Phoenix     Suns
# 10/30/2019  Washington       Wizards  Houston  Rockets
# 3/1/2019       Atlanta         Hawks  Chicago    Bulls

# %% [markdown]
# * Select the rows with points_home greater than 150, and home_team_wins not being 1, as well as the columns home_team_wins and points_home

# %%
games.loc[(games['points_home']>150)&(games['home_team_wins']!=1),['home_team_wins','points_home']]
# Out:
#             home_team_wins  points_home
# game_date
# 12/7/2006                0          157
# 10/30/2019               0          158
# 3/1/2019                 0          161

# %%
games=games.reset_index()

# %%
games.head(2)
# Out:
#     game_date game_status_text  points_home  points_away  home_team_wins  \
# 0  12/19/2020            Final          120          117               1
# 1  12/19/2020            Final           99           96               1
#
#     city_home nickname_home       city nickname
# 0     Orlando         Magic  Charlotte  Hornets
# 1  Washington       Wizards    Detroit  Pistons

# %% [markdown]
# *  Add a new column called points_total, as the sum of columns points_home and points_away

# %%
games['points_total'] = games['points_home'] + games['points_away']

# %%
games[['points_home', 'points_away', 'points_total']]
# Out:
#        points_home  points_away  points_total
# 0              120          117           237
# 1               99           96           195
# 2              116          117           233
# 3              107          113           220
# 4              105          117           222
# ...            ...          ...           ...
# 23416           93           87           180
# 23417           81           85           166
# 23418           98           95           193
# 23419           99           94           193
# 23420           86           98           184
#
# [23421 rows x 3 columns]

# %%
####Print out the 3 rows with the largest points_total using the nlargest method
games.nlargest(n=3, columns='points_total')
# Out:
#         game_date game_status_text  points_home  points_away  home_team_wins  \
# 16800    3/1/2019            Final          161          168               0
# 11596   12/7/2006            Final          157          161               0
# 16298  10/30/2019            Final          158          159               0
#
#         city_home nickname_home     city nickname  points_total
# 16800     Atlanta         Hawks  Chicago    Bulls           329
# 11596    Brooklyn          Nets  Phoenix     Suns           318
# 16298  Washington       Wizards  Houston  Rockets           317

# %%
games=games.sort_values(by='points_total')

# %%
games.tail(3)
# Out:
#         game_date game_status_text  points_home  points_away  home_team_wins  \
# 16298  10/30/2019            Final          158          159               0
# 11596   12/7/2006            Final          157          161               0
# 16800    3/1/2019            Final          161          168               0
#
#         city_home nickname_home     city nickname  points_total
# 16298  Washington       Wizards  Houston  Rockets           317
# 11596    Brooklyn          Nets  Phoenix     Suns           318
# 16800     Atlanta         Hawks  Chicago    Bulls           329

# %%
#SELECT THE ROW WITH THE SMALLEST POINTS_TOTAL USING ILOC.
games.iloc[0]
# Out:
# game_date           10/19/2007
# game_status_text         Final
# points_home                 36
# points_away                 33
# home_team_wins               1
# city_home               Boston
# nickname_home          Celtics
# city                  Brooklyn
# nickname                  Nets
# points_total                69
# Name: 10501, dtype: object

# %%
games.head()
# Out:
#         game_date game_status_text  points_home  points_away  home_team_wins  \
# 10501  10/19/2007            Final           36           33               1
# 16047   10/8/2003            Final           62           58               1
# 14676   11/9/2004            Final           64           60               1
# 13800   3/13/2005            Final           64           62               1
# 16006   11/1/2003            Final           73           56               1
#
#        city_home nickname_home      city       nickname  points_total
# 10501     Boston       Celtics  Brooklyn           Nets            69
# 16047    Indiana        Pacers   Chicago          Bulls           120
# 14676   Brooklyn          Nets  Portland  Trail Blazers           124
# 13800    Detroit       Pistons      Utah           Jazz           126
# 16006  Minnesota  Timberwolves   Toronto        Raptors           129

# %%
###SELECT THE ROWS WITH THE SECOND AND THIRD SMALLEST POINTS_TOTAL USING ILOC.
games.iloc[[1,2]]
# Out:
#        game_date game_status_text  points_home  points_away  home_team_wins  \
# 16047  10/8/2003            Final           62           58               1
# 14676  11/9/2004            Final           64           60               1
#
#       city_home nickname_home      city       nickname  points_total
# 16047   Indiana        Pacers   Chicago          Bulls           120
# 14676  Brooklyn          Nets  Portland  Trail Blazers           124

# %%
###SELECT A SUBSET INCLUDING THE FIRST 4 ROWS, AND THE FIRST 5 COLUMNS USING ILOC.
games.iloc[:4,:5]
# Out:
#         game_date game_status_text  points_home  points_away  home_team_wins
# 10501  10/19/2007            Final           36           33               1
# 16047   10/8/2003            Final           62           58               1
# 14676   11/9/2004            Final           64           60               1
# 13800   3/13/2005            Final           64           62               1
